# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import re

# Sample user input
user_description = "I'm looking    for a mystery novel with a sSrng female lead."

# Preprocessing
# Lowercase and remove punctuation
cleaned_description = re.sub(r'[^\w\s]', '', user_description.lower())

# Tokenization and stopword removal can be handled by TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words='english')
vectorized_description = vectorizer.fit_transform([cleaned_description])

print(cleaned_description)
# Out:
# im looking    for a mystery novel with a ssrng female lead

# %%
import pandas as pd
df = pd.read_csv("books_summary.csv")
df
# Out:
#       Unnamed: 0                                book_name  \
# 0              0              The Highly Sensitive Person
# 1              1      Why Has Nobody Told Me This Before?
# 2              2                     The Midnight Library
# 3              3                          Brave New World
# 4              4                                     1984
# ...          ...                                      ...
# 5196        5240                             Essentialism
# 5197        5241                     The Art Of Happiness
# 5198        5242                    The Paradox Of Choice
# 5199        5243                   Stumbling On Happiness
# 5200        5244  The 7 Habits Of Highly Effective People
#
#                                               summaries   categories
# 0      is a self-assessment guide and how-to-live te...      science
# 1      is a collection of a clinical psychologist’s ...      science
# 2      tells the story of Nora, a depressed woman in...      science
# 3      presents a futuristic society engineered perf...      science
# 4      is the story of a man questioning the system ...      science
# ...                                                 ...          ...
# 5196   will show you a new, better way of looking at...  mindfulness
# 5197   is the result of a psychiatrist interviewing ...  mindfulness
# 5198   shows you how today’s vast amount of choice m...  mindfulness
# 5199   examines the capacity of our brains to fill i...  mindfulness
# 5200   teaches you both personal and professional ef...  mindfulness
#
# [5201 rows x 4 columns]

# %%
df['categories'].unique()
# Out:
# array(['science', 'biography', 'politics', 'economics', 'environment',
#        'relationships', 'happiness', 'money', 'productivity',
#        'psychology', 'motivation', 'marketing', 'management', 'health',
#        'business', 'creativity', 'education', 'fiction', 'communication',
#        'religion', 'technology', 'work', 'mindfulness'], dtype=object)

# %%
print(df['summaries'][342])
# Out:
#  explains why the old positions of power aren’t as powerful as they used to be due to recent changes in society and technology and how this shift has put more influence in the hands of everyday citizens like you and what it might mean for the future of our governments and world.

# %%
df = df.drop('Unnamed: 0',axis = 1)

# %%
df.isnull().any()
# Out:
# book_name     False
# summaries      True
# categories    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# book_name     0
# summaries     7
# categories    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (5194, 3)

# %%
df.duplicated().any()
# Out:
# True

# %%
duplicate = df[df.duplicated(keep=False)]
duplicate
# Out:
#                                 book_name  \
# 0             The Highly Sensitive Person
# 1     Why Has Nobody Told Me This Before?
# 2                    The Midnight Library
# 3                         Brave New World
# 4                                    1984
# ...                                   ...
# 4894                      Brave New World
# 4895                         Stolen Focus
# 4896                       The Daily Laws
# 4897                      Dopamine Nation
# 4898                 The How of Happiness
#
#                                               summaries   categories
# 0      is a self-assessment guide and how-to-live te...      science
# 1      is a collection of a clinical psychologist’s ...      science
# 2      tells the story of Nora, a depressed woman in...      science
# 3      presents a futuristic society engineered perf...      science
# 4      is the story of a man questioning the system ...      science
# ...                                                 ...          ...
# 4894   presents a futuristic society engineered perf...  mindfulness
# 4895   explains why our attention spans have been dw...  mindfulness
# 4896   is a page-a-day, calendar-style book covering...  mindfulness
# 4897  talks about the importance of living a balance...  mindfulness
# 4898   describes a scientific approach to being happ...  mindfulness
#
# [444 rows x 3 columns]

# %%
(df['book_name'] == 'The Highly Sensitive Person').sum()
# Out:
# 12

# %%
filtered_df = df[df['book_name'] == 'The Highly Sensitive Person']

filtered_df
# Out:
#                         book_name  \
# 0     The Highly Sensitive Person
# 10    The Highly Sensitive Person
# 566   The Highly Sensitive Person
# 576   The Highly Sensitive Person
# 841   The Highly Sensitive Person
# 851   The Highly Sensitive Person
# 1905  The Highly Sensitive Person
# 1915  The Highly Sensitive Person
# 4128  The Highly Sensitive Person
# 4137  The Highly Sensitive Person
# 4511  The Highly Sensitive Person
# 4520  The Highly Sensitive Person
#
#                                               summaries     categories
# 0      is a self-assessment guide and how-to-live te...        science
# 10     is a self-assessment guide and how-to-live te...        science
# 566    is a self-assessment guide and how-to-live te...  relationships
# 576    is a self-assessment guide and how-to-live te...  relationships
# 841    is a self-assessment guide and how-to-live te...      happiness
# 851    is a self-assessment guide and how-to-live te...      happiness
# 1905   is a self-assessment guide and how-to-live te...     psychology
# 1915   is a self-assessment guide and how-to-live te...     psychology
# 4128   is a self-assessment guide and how-to-live te...  communication
# 4137   is a self-assessment guide and how-to-live te...  communication
# 4511   is a self-assessment guide and how-to-live te...           work
# 4520   is a self-assessment guide and how-to-live te...           work

# %%
filtered_df = df.groupby(['book_name', 'summaries'], as_index=False).agg({'categories': lambda x: ', '.join(sorted(set(x)))})

# %%
filtered_df
# Out:
#                                               book_name  \
# 0                               Outer Order, Inner Calm
# 1                                             The Book
# 2                                             #GIRLBOSS
# 3                             10 Days To Faster Reading
# 4                                           10% Happier
# ...                                                 ...
# 1225  Your Move: The Underdog’s Guide to Building Yo...
# 1226                  You’ll See It When You Believe It
# 1227                               You’re Not Listening
# 1228                                        Zero To One
# 1229                                               iWoz
#
#                                               summaries  \
# 0      gives you advice to declutter your space and ...
# 1     is a spiritual exploration of true human natur...
# 2      shows that even an unconventional life can le...
# 3      helps you bring your reading skills to the cu...
# 4      gives skeptics an easy “in” to meditation, by...
# ...                                                 ...
# 1225   is Ramit Sethi’s no-BS guide to starting your...
# 1226   shows you how to discover your true, best sel...
# 1227   is a book that will improve your communicatio...
# 1228   is an inside look at Peter Thiel’s philosophy...
# 1229   is Steve Wozniak’s autobiography, detailing h...
#
#                                              categories
# 0     happiness, health, mindfulness, productivity, ...
# 1                                           mindfulness
# 2                business, creativity, motivation, work
# 3                   education, productivity, psychology
# 4                    happiness, mindfulness, psychology
# ...                                                 ...
# 1225                   business, marketing, money, work
# 1226         motivation, productivity, psychology, work
# 1227  business, communication, happiness, management...
# 1228  business, management, marketing, motivation, p...
# 1229              biography, business, technology, work
#
# [1230 rows x 3 columns]

# %%
(filtered_df['book_name'] == 'The Highly Sensitive Person').sum()
# Out:
# 1

# %%
filtered_df[filtered_df['book_name'] == 'The Highly Sensitive Person']
# Out:
#                        book_name  \
# 915  The Highly Sensitive Person
#
#                                              summaries  \
# 915   is a self-assessment guide and how-to-live te...
#
#                                             categories
# 915  communication, happiness, psychology, relation...

# %%
data = []
import csv
from tqdm import tqdm
with open("booksummaries.txt", 'r', encoding='utf-8') as f:
    reader = csv.reader(f, dialect='excel-tab')
    for row in tqdm(reader):
        data.append(row)
# Out:
# 16559it [00:00, 67480.42it/s]

# %%
book_id = []
book_name = []
summary = []
genre = []

for i in tqdm(data):
    book_id.append(i[0])
    book_name.append(i[2])
    genre.append(i[5])
    summary.append(i[6])

books = pd.DataFrame({'book_id': book_id, 'book_name': book_name,
                       'genre': genre, 'summary': summary})
books
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 16559/16559 [00:00<00:00, 2369536.35it/s]
#         book_id                                          book_name  \
# 0           620                                        Animal Farm
# 1           843                                 A Clockwork Orange
# 2           986                                         The Plague
# 3          1756          An Enquiry Concerning Human Understanding
# 4          2080                               A Fire Upon the Deep
# ...         ...                                                ...
# 16554  36934824                                     Under Wildwood
# 16555  37054020                                  Transfer of Power
# 16556  37122323                                            Decoded
# 16557  37132319  America Again: Re-becoming The Greatness We Ne...
# 16558  37159503                                          Poor Folk
#
#                                                    genre  \
# 0      {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
# 1      {"/m/06n90": "Science Fiction", "/m/0l67h": "N...
# 2      {"/m/02m4t": "Existentialism", "/m/02xlf": "Fi...
# 3
# 4      {"/m/03lrw": "Hard science fiction", "/m/06n90...
# ...                                                  ...
# 16554
# 16555   {"/m/01jfsb": "Thriller", "/m/02xlf": "Fiction"}
# 16556                       {"/m/0xdf": "Autobiography"}
# 16557
# 16558  {"/m/02ql9": "Epistolary novel", "/m/014dfn": ...
#
#                                                  summary
# 0       Old Major, the old boar on the Manor Farm, ca...
# 1       Alex, a teenager living in near-future Englan...
# 2       The text of The Plague is divided into five p...
# 3       The argument of the Enquiry proceeds by a ser...
# 4       The novel posits that space around the Milky ...
# ...                                                  ...
# 16554   Prue McKeel, having rescued her brother from ...
# 16555   The reader first meets Rapp while he is doing...
# 16556   The book follows very rough chronological ord...
# 16557   Colbert addresses topics including Wall Stree...
# 16558   Makar Devushkin and Varvara Dobroselova are s...
#
# [16559 rows x 4 columns]

# %%
books.isnull().sum()
# Out:
# book_id      0
# book_name    0
# genre        0
# summary      0
# dtype: int64

# %%
import numpy as np

mask = books['genre'].apply(lambda x: x == '' or pd.isna(x) or not isinstance(x, str) or (isinstance(x, str) and not x.startswith('{')))

# Replace identified values with NaN
books.loc[mask, 'genre'] = np.nan

# Now check for null values again
null_values = books.isnull().sum()

print(null_values)
# Out:
# book_id         0
# book_name       0
# genre        3718
# summary         0
# dtype: int64

# %%
books.drop("book_id", axis = 1, inplace = True)

# %%
books
# Out:
#                                                book_name  \
# 0                                            Animal Farm
# 1                                     A Clockwork Orange
# 2                                             The Plague
# 3              An Enquiry Concerning Human Understanding
# 4                                   A Fire Upon the Deep
# ...                                                  ...
# 16554                                     Under Wildwood
# 16555                                  Transfer of Power
# 16556                                            Decoded
# 16557  America Again: Re-becoming The Greatness We Ne...
# 16558                                          Poor Folk
#
#                                                    genre  \
# 0      {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
# 1      {"/m/06n90": "Science Fiction", "/m/0l67h": "N...
# 2      {"/m/02m4t": "Existentialism", "/m/02xlf": "Fi...
# 3                                                    NaN
# 4      {"/m/03lrw": "Hard science fiction", "/m/06n90...
# ...                                                  ...
# 16554                                                NaN
# 16555   {"/m/01jfsb": "Thriller", "/m/02xlf": "Fiction"}
# 16556                       {"/m/0xdf": "Autobiography"}
# 16557                                                NaN
# 16558  {"/m/02ql9": "Epistolary novel", "/m/014dfn": ...
#
#                                                  summary
# 0       Old Major, the old boar on the Manor Farm, ca...
# 1       Alex, a teenager living in near-future Englan...
# 2       The text of The Plague is divided into five p...
# 3       The argument of the Enquiry proceeds by a ser...
# 4       The novel posits that space around the Milky ...
# ...                                                  ...
# 16554   Prue McKeel, having rescued her brother from ...
# 16555   The reader first meets Rapp while he is doing...
# 16556   The book follows very rough chronological ord...
# 16557   Colbert addresses topics including Wall Stree...
# 16558   Makar Devushkin and Varvara Dobroselova are s...
#
# [16559 rows x 3 columns]

# %%
import json

# %%
def extract_genres(genre):
    if pd.isna(genre) or genre == '':
        return np.nan
    try:
        genre_dict = json.loads(genre)
        genre_values = list(genre_dict.values())
        return ', '.join(genre_values)
    except (json.JSONDecodeError, TypeError):
        return np.nan

# %%
books['genre'] = books['genre'].apply(extract_genres)

# %%
books
# Out:
#                                                book_name  \
# 0                                            Animal Farm
# 1                                     A Clockwork Orange
# 2                                             The Plague
# 3              An Enquiry Concerning Human Understanding
# 4                                   A Fire Upon the Deep
# ...                                                  ...
# 16554                                     Under Wildwood
# 16555                                  Transfer of Power
# 16556                                            Decoded
# 16557  America Again: Re-becoming The Greatness We Ne...
# 16558                                          Poor Folk
#
#                                                    genre  \
# 0      Roman à clef, Satire, Children's literature, S...
# 1      Science Fiction, Novella, Speculative fiction,...
# 2      Existentialism, Fiction, Absurdist fiction, Novel
# 3                                                    NaN
# 4      Hard science fiction, Science Fiction, Specula...
# ...                                                  ...
# 16554                                                NaN
# 16555                                  Thriller, Fiction
# 16556                                      Autobiography
# 16557                                                NaN
# 16558              Epistolary novel, Speculative fiction
#
#                                                  summary
# 0       Old Major, the old boar on the Manor Farm, ca...
# 1       Alex, a teenager living in near-future Englan...
# 2       The text of The Plague is divided into five p...
# 3       The argument of the Enquiry proceeds by a ser...
# 4       The novel posits that space around the Milky ...
# ...                                                  ...
# 16554   Prue McKeel, having rescued her brother from ...
# 16555   The reader first meets Rapp while he is doing...
# 16556   The book follows very rough chronological ord...
# 16557   Colbert addresses topics including Wall Stree...
# 16558   Makar Devushkin and Varvara Dobroselova are s...
#
# [16559 rows x 3 columns]

# %%
filtered_df.rename(columns={'summaries': 'summary', 'categories': 'genre'}, inplace=True)

# %%
books
# Out:
#                                                book_name  \
# 0                                            Animal Farm
# 1                                     A Clockwork Orange
# 2                                             The Plague
# 3              An Enquiry Concerning Human Understanding
# 4                                   A Fire Upon the Deep
# ...                                                  ...
# 16554                                     Under Wildwood
# 16555                                  Transfer of Power
# 16556                                            Decoded
# 16557  America Again: Re-becoming The Greatness We Ne...
# 16558                                          Poor Folk
#
#                                                    genre  \
# 0      Roman à clef, Satire, Children's literature, S...
# 1      Science Fiction, Novella, Speculative fiction,...
# 2      Existentialism, Fiction, Absurdist fiction, Novel
# 3                                                    NaN
# 4      Hard science fiction, Science Fiction, Specula...
# ...                                                  ...
# 16554                                                NaN
# 16555                                  Thriller, Fiction
# 16556                                      Autobiography
# 16557                                                NaN
# 16558              Epistolary novel, Speculative fiction
#
#                                                  summary
# 0       Old Major, the old boar on the Manor Farm, ca...
# 1       Alex, a teenager living in near-future Englan...
# 2       The text of The Plague is divided into five p...
# 3       The argument of the Enquiry proceeds by a ser...
# 4       The novel posits that space around the Milky ...
# ...                                                  ...
# 16554   Prue McKeel, having rescued her brother from ...
# 16555   The reader first meets Rapp while he is doing...
# 16556   The book follows very rough chronological ord...
# 16557   Colbert addresses topics including Wall Stree...
# 16558   Makar Devushkin and Varvara Dobroselova are s...
#
# [16559 rows x 3 columns]

# %%
filtered_df
# Out:
#                                               book_name  \
# 0                               Outer Order, Inner Calm
# 1                                             The Book
# 2                                             #GIRLBOSS
# 3                             10 Days To Faster Reading
# 4                                           10% Happier
# ...                                                 ...
# 1225  Your Move: The Underdog’s Guide to Building Yo...
# 1226                  You’ll See It When You Believe It
# 1227                               You’re Not Listening
# 1228                                        Zero To One
# 1229                                               iWoz
#
#                                                 summary  \
# 0      gives you advice to declutter your space and ...
# 1     is a spiritual exploration of true human natur...
# 2      shows that even an unconventional life can le...
# 3      helps you bring your reading skills to the cu...
# 4      gives skeptics an easy “in” to meditation, by...
# ...                                                 ...
# 1225   is Ramit Sethi’s no-BS guide to starting your...
# 1226   shows you how to discover your true, best sel...
# 1227   is a book that will improve your communicatio...
# 1228   is an inside look at Peter Thiel’s philosophy...
# 1229   is Steve Wozniak’s autobiography, detailing h...
#
#                                                   genre
# 0     happiness, health, mindfulness, productivity, ...
# 1                                           mindfulness
# 2                business, creativity, motivation, work
# 3                   education, productivity, psychology
# 4                    happiness, mindfulness, psychology
# ...                                                 ...
# 1225                   business, marketing, money, work
# 1226         motivation, productivity, psychology, work
# 1227  business, communication, happiness, management...
# 1228  business, management, marketing, motivation, p...
# 1229              biography, business, technology, work
#
# [1230 rows x 3 columns]

# %%
combined_df = pd.concat([books, filtered_df])

# %%
df = combined_df

# %%
df['summary'] = df['summary'].str.lower()

# %%
df['genre'] = df['genre'].str.lower()

# %%
df
# Out:
#                                               book_name  \
# 0                                           Animal Farm
# 1                                    A Clockwork Orange
# 2                                            The Plague
# 3             An Enquiry Concerning Human Understanding
# 4                                  A Fire Upon the Deep
# ...                                                 ...
# 1225  Your Move: The Underdog’s Guide to Building Yo...
# 1226                  You’ll See It When You Believe It
# 1227                               You’re Not Listening
# 1228                                        Zero To One
# 1229                                               iWoz
#
#                                                   genre  \
# 0     Roman à clef, Satire, Children's literature, S...
# 1     Science Fiction, Novella, Speculative fiction,...
# 2     Existentialism, Fiction, Absurdist fiction, Novel
# 3                                                   NaN
# 4     Hard science fiction, Science Fiction, Specula...
# ...                                                 ...
# 1225                   business, marketing, money, work
# 1226         motivation, productivity, psychology, work
# 1227  business, communication, happiness, management...
# 1228  business, management, marketing, motivation, p...
# 1229              biography, business, technology, work
#
#                                                 summary
# 0      old major, the old boar on the manor farm, ca...
# 1      alex, a teenager living in near-future englan...
# 2      the text of the plague is divided into five p...
# 3      the argument of the enquiry proceeds by a ser...
# 4      the novel posits that space around the milky ...
# ...                                                 ...
# 1225   is ramit sethi’s no-bs guide to starting your...
# 1226   shows you how to discover your true, best sel...
# 1227   is a book that will improve your communicatio...
# 1228   is an inside look at peter thiel’s philosophy...
# 1229   is steve wozniak’s autobiography, detailing h...
#
# [17789 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17789 entries, 0 to 1229
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   book_name  17789 non-null  object
#  1   genre      14071 non-null  object
#  2   summary    17789 non-null  object
# dtypes: object(3)
# memory usage: 555.9+ KB

# %%
import string
df['summary'] = df['summary'].apply(lambda x: ''.join([char for char in x if char not in string.punctuation]))

# %%
df
# Out:
#                                               book_name  \
# 0                                           Animal Farm
# 1                                    A Clockwork Orange
# 2                                            The Plague
# 3             An Enquiry Concerning Human Understanding
# 4                                  A Fire Upon the Deep
# ...                                                 ...
# 1225  Your Move: The Underdog’s Guide to Building Yo...
# 1226                  You’ll See It When You Believe It
# 1227                               You’re Not Listening
# 1228                                        Zero To One
# 1229                                               iWoz
#
#                                                   genre  \
# 0     roman à clef, satire, children's literature, s...
# 1     science fiction, novella, speculative fiction,...
# 2     existentialism, fiction, absurdist fiction, novel
# 3                                                   NaN
# 4     hard science fiction, science fiction, specula...
# ...                                                 ...
# 1225                   business, marketing, money, work
# 1226         motivation, productivity, psychology, work
# 1227  business, communication, happiness, management...
# 1228  business, management, marketing, motivation, p...
# 1229              biography, business, technology, work
#
#                                                 summary
# 0      old major the old boar on the manor farm call...
# 1      alex a teenager living in nearfuture england ...
# 2      the text of the plague is divided into five p...
# 3      the argument of the enquiry proceeds by a ser...
# 4      the novel posits that space around the milky ...
# ...                                                 ...
# 1225   is ramit sethi’s nobs guide to starting your ...
# 1226   shows you how to discover your true best self...
# 1227   is a book that will improve your communicatio...
# 1228   is an inside look at peter thiel’s philosophy...
# 1229   is steve wozniak’s autobiography detailing hi...
#
# [17789 rows x 3 columns]

# %%
df
# Out:
#                                               book_name  \
# 0                                           Animal Farm
# 1                                    A Clockwork Orange
# 2                                            The Plague
# 3             An Enquiry Concerning Human Understanding
# 4                                  A Fire Upon the Deep
# ...                                                 ...
# 1225  Your Move: The Underdog’s Guide to Building Yo...
# 1226                  You’ll See It When You Believe It
# 1227                               You’re Not Listening
# 1228                                        Zero To One
# 1229                                               iWoz
#
#                                                   genre  \
# 0     roman à clef, satire, children's literature, s...
# 1     science fiction, novella, speculative fiction,...
# 2     existentialism, fiction, absurdist fiction, novel
# 3                                                   NaN
# 4     hard science fiction, science fiction, specula...
# ...                                                 ...
# 1225                   business, marketing, money, work
# 1226         motivation, productivity, psychology, work
# 1227  business, communication, happiness, management...
# 1228  business, management, marketing, motivation, p...
# 1229              biography, business, technology, work
#
#                                                 summary
# 0      old major the old boar on the manor farm call...
# 1      alex a teenager living in nearfuture england ...
# 2      the text of the plague is divided into five p...
# 3      the argument of the enquiry proceeds by a ser...
# 4      the novel posits that space around the milky ...
# ...                                                 ...
# 1225   is ramit sethi’s nobs guide to starting your ...
# 1226   shows you how to discover your true best self...
# 1227   is a book that will improve your communicatio...
# 1228   is an inside look at peter thiel’s philosophy...
# 1229   is steve wozniak’s autobiography detailing hi...
#
# [17789 rows x 3 columns]

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
df['summary'] = df['summary'].apply(word_tokenize)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\devam\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\devam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df
# Out:
#                                               book_name  \
# 0                                           Animal Farm
# 1                                    A Clockwork Orange
# 2                                            The Plague
# 3             An Enquiry Concerning Human Understanding
# 4                                  A Fire Upon the Deep
# ...                                                 ...
# 1225  Your Move: The Underdog’s Guide to Building Yo...
# 1226                  You’ll See It When You Believe It
# 1227                               You’re Not Listening
# 1228                                        Zero To One
# 1229                                               iWoz
#
#                                                   genre  \
# 0     roman à clef, satire, children's literature, s...
# 1     science fiction, novella, speculative fiction,...
# 2     existentialism, fiction, absurdist fiction, novel
# 3                                                   NaN
# 4     hard science fiction, science fiction, specula...
# ...                                                 ...
# 1225                   business, marketing, money, work
# 1226         motivation, productivity, psychology, work
# 1227  business, communication, happiness, management...
# 1228  business, management, marketing, motivation, p...
# 1229              biography, business, technology, work
#
#                                                 summary
# 0     [old, major, the, old, boar, on, the, manor, f...
# 1     [alex, a, teenager, living, in, nearfuture, en...
# 2     [the, text, of, the, plague, is, divided, into...
# 3     [the, argument, of, the, enquiry, proceeds, by...
# 4     [the, novel, posits, that, space, around, the,...
# ...                                                 ...
# 1225  [is, ramit, sethi, ’, s, nobs, guide, to, star...
# 1226  [shows, you, how, to, discover, your, true, be...
# 1227  [is, a, book, that, will, improve, your, commu...
# 1228  [is, an, inside, look, at, peter, thiel, ’, s,...
# 1229  [is, steve, wozniak, ’, s, autobiography, deta...
#
# [17789 rows x 3 columns]

# %%
df
# Out:
#                                               book_name  \
# 0                                           Animal Farm
# 1                                    A Clockwork Orange
# 2                                            The Plague
# 3             An Enquiry Concerning Human Understanding
# 4                                  A Fire Upon the Deep
# ...                                                 ...
# 1225  Your Move: The Underdog’s Guide to Building Yo...
# 1226                  You’ll See It When You Believe It
# 1227                               You’re Not Listening
# 1228                                        Zero To One
# 1229                                               iWoz
#
#                                                   genre  \
# 0     roman à clef, satire, children's literature, s...
# 1     science fiction, novella, speculative fiction,...
# 2     existentialism, fiction, absurdist fiction, novel
# 3                                                   NaN
# 4     hard science fiction, science fiction, specula...
# ...                                                 ...
# 1225                   business, marketing, money, work
# 1226         motivation, productivity, psychology, work
# 1227  business, communication, happiness, management...
# 1228  business, management, marketing, motivation, p...
# 1229              biography, business, technology, work
#
#                                                 summary
# 0     [old, major, the, old, boar, on, the, manor, f...
# 1     [alex, a, teenager, living, in, nearfuture, en...
# 2     [the, text, of, the, plague, is, divided, into...
# 3     [the, argument, of, the, enquiry, proceeds, by...
# 4     [the, novel, posits, that, space, around, the,...
# ...                                                 ...
# 1225  [is, ramit, sethi, ’, s, nobs, guide, to, star...
# 1226  [shows, you, how, to, discover, your, true, be...
# 1227  [is, a, book, that, will, improve, your, commu...
# 1228  [is, an, inside, look, at, peter, thiel, ’, s,...
# 1229  [is, steve, wozniak, ’, s, autobiography, deta...
#
# [17789 rows x 3 columns]

# %%
from nltk.corpus import stopwords 

stop_words = set(stopwords.words('english'))
df['summary'] = df['summary'].apply(lambda x: [word for word in x if word not in stop_words])

# %%
df
# Out:
#                                               book_name  \
# 0                                           Animal Farm
# 1                                    A Clockwork Orange
# 2                                            The Plague
# 3             An Enquiry Concerning Human Understanding
# 4                                  A Fire Upon the Deep
# ...                                                 ...
# 1225  Your Move: The Underdog’s Guide to Building Yo...
# 1226                  You’ll See It When You Believe It
# 1227                               You’re Not Listening
# 1228                                        Zero To One
# 1229                                               iWoz
#
#                                                   genre  \
# 0     roman à clef, satire, children's literature, s...
# 1     science fiction, novella, speculative fiction,...
# 2     existentialism, fiction, absurdist fiction, novel
# 3                                                   NaN
# 4     hard science fiction, science fiction, specula...
# ...                                                 ...
# 1225                   business, marketing, money, work
# 1226         motivation, productivity, psychology, work
# 1227  business, communication, happiness, management...
# 1228  business, management, marketing, motivation, p...
# 1229              biography, business, technology, work
#
#                                                 summary
# 0     [old, major, old, boar, manor, farm, calls, an...
# 1     [alex, teenager, living, nearfuture, england, ...
# 2     [text, plague, divided, five, parts, town, ora...
# 3     [argument, enquiry, proceeds, series, incremen...
# 4     [novel, posits, space, around, milky, way, div...
# ...                                                 ...
# 1225  [ramit, sethi, ’, nobs, guide, starting, busin...
# 1226  [shows, discover, true, best, self, revealing,...
# 1227  [book, improve, communication, skills, reveali...
# 1228  [inside, look, peter, thiel, ’, philosophy, st...
# 1229  [steve, wozniak, ’, autobiography, detailing, ...
#
# [17789 rows x 3 columns]

# %%
df
# Out:
#                                               book_name  \
# 0                                           Animal Farm
# 1                                    A Clockwork Orange
# 2                                            The Plague
# 3             An Enquiry Concerning Human Understanding
# 4                                  A Fire Upon the Deep
# ...                                                 ...
# 1225  Your Move: The Underdog’s Guide to Building Yo...
# 1226                  You’ll See It When You Believe It
# 1227                               You’re Not Listening
# 1228                                        Zero To One
# 1229                                               iWoz
#
#                                                   genre  \
# 0     roman à clef, satire, children's literature, s...
# 1     science fiction, novella, speculative fiction,...
# 2     existentialism, fiction, absurdist fiction, novel
# 3                                                   NaN
# 4     hard science fiction, science fiction, specula...
# ...                                                 ...
# 1225                   business, marketing, money, work
# 1226         motivation, productivity, psychology, work
# 1227  business, communication, happiness, management...
# 1228  business, management, marketing, motivation, p...
# 1229              biography, business, technology, work
#
#                                                 summary
# 0     [old, major, old, boar, manor, farm, calls, an...
# 1     [alex, teenager, living, nearfuture, england, ...
# 2     [text, plague, divided, five, parts, town, ora...
# 3     [argument, enquiry, proceeds, series, incremen...
# 4     [novel, posits, space, around, milky, way, div...
# ...                                                 ...
# 1225  [ramit, sethi, ’, nobs, guide, starting, busin...
# 1226  [shows, discover, true, best, self, revealing,...
# 1227  [book, improve, communication, skills, reveali...
# 1228  [inside, look, peter, thiel, ’, philosophy, st...
# 1229  [steve, wozniak, ’, autobiography, detailing, ...
#
# [17789 rows x 3 columns]

# %%
from nltk.stem import WordNetLemmatizer

def lemmatize_list(word_list):
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in word_list]
    return lemmatized_words

df['lemmatized_summary'] = df['summary'].apply(lemmatize_list)

# %%
df
# Out:
#                                               book_name  \
# 0                                           Animal Farm
# 1                                    A Clockwork Orange
# 2                                            The Plague
# 3             An Enquiry Concerning Human Understanding
# 4                                  A Fire Upon the Deep
# ...                                                 ...
# 1225  Your Move: The Underdog’s Guide to Building Yo...
# 1226                  You’ll See It When You Believe It
# 1227                               You’re Not Listening
# 1228                                        Zero To One
# 1229                                               iWoz
#
#                                                   genre  \
# 0     roman à clef, satire, children's literature, s...
# 1     science fiction, novella, speculative fiction,...
# 2     existentialism, fiction, absurdist fiction, novel
# 3                                                   NaN
# 4     hard science fiction, science fiction, specula...
# ...                                                 ...
# 1225                   business, marketing, money, work
# 1226         motivation, productivity, psychology, work
# 1227  business, communication, happiness, management...
# 1228  business, management, marketing, motivation, p...
# 1229              biography, business, technology, work
#
#                                                 summary  \
# 0     [old, major, old, boar, manor, farm, calls, an...
# 1     [alex, teenager, living, nearfuture, england, ...
# 2     [text, plague, divided, five, parts, town, ora...
# 3     [argument, enquiry, proceeds, series, incremen...
# 4     [novel, posits, space, around, milky, way, div...
# ...                                                 ...
# 1225  [ramit, sethi, ’, nobs, guide, starting, busin...
# 1226  [shows, discover, true, best, self, revealing,...
# 1227  [book, improve, communication, skills, reveali...
# 1228  [inside, look, peter, thiel, ’, philosophy, st...
# 1229  [steve, wozniak, ’, autobiography, detailing, ...
#
#                                      lemmatized_summary
# 0     [old, major, old, boar, manor, farm, call, ani...
# 1     [alex, teenager, living, nearfuture, england, ...
# 2     [text, plague, divided, five, part, town, oran...
# 3     [argument, enquiry, proceeds, series, incremen...
# 4     [novel, posit, space, around, milky, way, divi...
# ...                                                 ...
# 1225  [ramit, sethi, ’, nob, guide, starting, busine...
# 1226  [show, discover, true, best, self, revealing, ...
# 1227  [book, improve, communication, skill, revealin...
# 1228  [inside, look, peter, thiel, ’, philosophy, st...
# 1229  [steve, wozniak, ’, autobiography, detailing, ...
#
# [17789 rows x 4 columns]

# %%
df['lemmatized_summary'] == df['summary']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1225    False
# 1226    False
# 1227    False
# 1228    False
# 1229    False
# Length: 17789, dtype: bool

# %%
df['summary'] = df['lemmatized_summary']

# %%
df.drop('lemmatized_summary',axis = 1)
# Out:
#                                               book_name  \
# 0                                           Animal Farm
# 1                                    A Clockwork Orange
# 2                                            The Plague
# 3             An Enquiry Concerning Human Understanding
# 4                                  A Fire Upon the Deep
# ...                                                 ...
# 1225  Your Move: The Underdog’s Guide to Building Yo...
# 1226                  You’ll See It When You Believe It
# 1227                               You’re Not Listening
# 1228                                        Zero To One
# 1229                                               iWoz
#
#                                                   genre  \
# 0     roman à clef, satire, children's literature, s...
# 1     science fiction, novella, speculative fiction,...
# 2     existentialism, fiction, absurdist fiction, novel
# 3                                                   NaN
# 4     hard science fiction, science fiction, specula...
# ...                                                 ...
# 1225                   business, marketing, money, work
# 1226         motivation, productivity, psychology, work
# 1227  business, communication, happiness, management...
# 1228  business, management, marketing, motivation, p...
# 1229              biography, business, technology, work
#
#                                                 summary
# 0     [old, major, old, boar, manor, farm, call, ani...
# 1     [alex, teenager, living, nearfuture, england, ...
# 2     [text, plague, divided, five, part, town, oran...
# 3     [argument, enquiry, proceeds, series, incremen...
# 4     [novel, posit, space, around, milky, way, divi...
# ...                                                 ...
# 1225  [ramit, sethi, ’, nob, guide, starting, busine...
# 1226  [show, discover, true, best, self, revealing, ...
# 1227  [book, improve, communication, skill, revealin...
# 1228  [inside, look, peter, thiel, ’, philosophy, st...
# 1229  [steve, wozniak, ’, autobiography, detailing, ...
#
# [17789 rows x 3 columns]

# %%
df['summary'] = df['summary'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
df
df.drop('lemmatized_summary',axis = 1)
# Out:
#                                               book_name  \
# 0                                           Animal Farm
# 1                                    A Clockwork Orange
# 2                                            The Plague
# 3             An Enquiry Concerning Human Understanding
# 4                                  A Fire Upon the Deep
# ...                                                 ...
# 1225  Your Move: The Underdog’s Guide to Building Yo...
# 1226                  You’ll See It When You Believe It
# 1227                               You’re Not Listening
# 1228                                        Zero To One
# 1229                                               iWoz
#
#                                                   genre  \
# 0     roman à clef, satire, children's literature, s...
# 1     science fiction, novella, speculative fiction,...
# 2     existentialism, fiction, absurdist fiction, novel
# 3                                                   NaN
# 4     hard science fiction, science fiction, specula...
# ...                                                 ...
# 1225                   business, marketing, money, work
# 1226         motivation, productivity, psychology, work
# 1227  business, communication, happiness, management...
# 1228  business, management, marketing, motivation, p...
# 1229              biography, business, technology, work
#
#                                                 summary
# 0     old major old boar manor farm call animal farm...
# 1     alex teenager living nearfuture england lead g...
# 2     text plague divided five part town oran thousa...
# 3     argument enquiry proceeds series incremental s...
# 4     novel posit space around milky way divided con...
# ...                                                 ...
# 1225  ramit sethi ’ nob guide starting business ’ he...
# 1226  show discover true best self revealing use pow...
# 1227  book improve communication skill revealing unc...
# 1228  inside look peter thiel ’ philosophy strategy ...
# 1229  steve wozniak ’ autobiography detailing story ...
#
# [17789 rows x 3 columns]

# %%
df.loc[1555:1666]
# Out:
#                         book_name  \
# 1555  Akhenaten, Dweller in Truth
# 1556                  Faerie Tale
# 1557                       Lirael
# 1558                     Abhorsen
# 1559    The Girl Who Owned a City
# ...                           ...
# 1662    Les amitiés particulières
# 1663           The Worm Ouroboros
# 1664                   Rising Sun
# 1665    Norby, the Mixed-Up Robot
# 1666                 Glory Season
#
#                                                   genre  \
# 1555                                     history, novel
# 1556                       speculative fiction, fantasy
# 1557  science fiction, children's literature, fantas...
# 1558  children's literature, fantasy, speculative fi...
# 1559  science fiction, apocalyptic and post-apocalyp...
# ...                                                 ...
# 1662                                                NaN
# 1663  science fiction, speculative fiction, fantasy,...
# 1664  crime fiction, mystery, science fiction, ficti...
# 1665               science fiction, speculative fiction
# 1666  science fiction, speculative fiction, children...
#
#                                                 summary  \
# 1555  way thebe father scribe amunhoben point ruin a...
# 1556  phil hastings family moved back hometown much ...
# 1557  lirael see outcast within world clayr ravenbla...
# 1558  main novel begin abhorsens house besieged dead...
# 1559  deadly virus swept world killing everyone age ...
# ...                                                 ...
# 1662  plot revolves around george de sarre fourteeny...
# 1663  framing story first two chapter describes worl...
# 1664  nakamoto corporation celebrating grand opening...
# 1665  book start jeff need teaching robot buy norby ...
# 1666  three thousand year story start lysos founder ...
#
#                                      lemmatized_summary
# 1555  [way, thebe, father, scribe, amunhoben, point,...
# 1556  [phil, hastings, family, moved, back, hometown...
# 1557  [lirael, see, outcast, within, world, clayr, r...
# 1558  [main, novel, begin, abhorsens, house, besiege...
# 1559  [deadly, virus, swept, world, killing, everyon...
# ...                                                 ...
# 1662  [plot, revolves, around, george, de, sarre, fo...
# 1663  [framing, story, first, two, chapter, describe...
# 1664  [nakamoto, corporation, celebrating, grand, op...
# 1665  [book, start, jeff, need, teaching, robot, buy...
# 1666  [three, thousand, year, story, start, lysos, f...
#
# [112 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Step 1: Convert summaries to vectors
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['summary'])

# Step 2: Function to recommend books based on user description
def recommend_books(user_description, df, X, vectorizer, top_n=5):
    # Transform user input
    user_vec = vectorizer.transform([user_description])
    
    # Calculate cosine similarity
    similarities = cosine_similarity(user_vec, X)
    
    # Find top N matches
    top_n_indices = similarities.argsort()[0][-top_n:][::-1]
    
    # Return the top N recommended books
    return df.iloc[top_n_indices][['book_name', 'genre', 'summary']]

# Example usage
user_description = "a book based on a college campus"
recommended_books = recommend_books(user_description, df, X, vectorizer)
recommended_books
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sklearn.feature_extraction.text import TfidfVectorizer
#       2 from sklearn.metrics.pairwise import cosine_similarity
#       4 # Step 1: Convert summaries to vectors
#
# ModuleNotFoundError: No module named 'sklearn'
